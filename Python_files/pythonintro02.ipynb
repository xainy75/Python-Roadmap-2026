# %% [markdown]
# Topic 27 | Importing & Using Python Modules
# This topic teaches how to import built‐in modules like math, random, and os. Learners understand import and from…import statements.

# %%
import math
print(math.sqrt(16))
# Out:
# 4.0

# %%
form math import sqrt
print(sqrt(16))
# Out:
#   Cell In[2], line 2
#     form math import sqrt
#          ^
# SyntaxError: invalid syntax

# %%
import mymodule
mymodule.greet()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import mymodule
#       2 mymodule.greet()
#
# ModuleNotFoundError: No module named 'mymodule'

# %% [markdown]
# Topic 28 | Understanding the Need For OOP
# This topic introduces Object‐Oriented Programming and why it is needed. Learners understand how OOP improves structure and reusability.

# %% [markdown]
# Topic 29 | Core OOP Concepts - Classes, Objects, Methods & Attributes
# This topic explains foundational OOP concepts such as classes, objects, methods, and attributes. Learners understand how OOP organizes code.

# %%
class car:
    def __init__(self, color):
        self.color = color

    def start(self):
        print(f"The {self.color} car has started.")

my_car = car("red")
my_car.start()

my_brother = car("red")
print(my_car.color)
# Out:
# The red car has started.
# red

# %% [markdown]
# Topic 30 | Defining a Class & Creating Objects
# This topic teaches how to write classes and create objects from them. Learners begin applying OOP in practical code.

# %%
class car:
    def drive(self):
        print("The car is driving.")

my_car = car()
my_car.drive()
# Out:
# The car is driving.

# %%
class car:
    color = "red"
    def drive(self):
        print(f"The {self.color} car is driving.")

    def setcolor(self, new_color):
        self.color = new_color
my_car = car()
my_car.drive()
car2 = car()
car.setcolor(car2, "blue")
car2.drive()
# Out:
# The red car is driving.
# The blue car is driving.

# %% [markdown]
# Topic 31 | The __init__() Constructor Method
# This topic explains the purpose of the init() constructor and how it initializes object attributes.

# %%
class dog:
    def __init__(self):
        self.name = "Buddy"
    def bark(self):
        print(f"{self.name} says Woof!")
dog1 = dog()
dog1.bark()
# Out:
# Buddy says Woof!

# %%
class Car:
    def __init__(self, brand, color):
        self.brand = brand
        self.color = color
car1 = Car("Toyota", "red")
print(car1.brand)
print(car1.color)

car.color = "blue"
car2 = Car("Honda", "blue")
print(car2.brand)
print(car2.color)
# Out:
# Toyota
# red
# Honda
# blue

# %% [markdown]
# Topic 32 | Instance Variables & Instance Methods
# This topic explains how instance variables and methods work inside classes. Learners understand how objects store and use data.

# %%
class Student:
    def __init__(self, name, age, grade):
        self.name = name
        self.age = age
        self.grade = grade
    def display_info(self):
        print(f"Student Name: {self.name}")
        print(f"Age: {self.age}")
        print(f"Grade: {self.grade}")
    def is_eligible(self):
        if self.age >= 15:
            print(f"{self.name} is eligible for admission.")
        else:
            print(f"{self.name} is not eligible for admission.")

student1 = Student("Alice", 16, "A")
student1.display_info()
student1.is_eligible()
# Out:
# Student Name: Alice
# Age: 16
# Grade: A
# Alice is eligible for admission.

# %% [markdown]
# Topic 33 | Accessing Object Attributes & Methods
# This topic shows how to access attributes and call methods on objects. Learners practice interacting with object data.

# %%
class Student:
    def __init__(self, name, age, grade):
        self.name = name
        self.age = age
        self.grade = grade
    def display_info(self):
        print(f"Student Name: {self.name}")
        print(f"Age: {self.age}")
        print(f"Grade: {self.grade}")
    def is_eligible(self):
        if self.age >= 15:
            print(f"{self.name} is eligible for admission.")
        else:
            print(f"{self.name} is not eligible for admission.")

#Creating objects of the Student class and calling
student1 = Student("Alice", 16, "A")
student1.display_info()
student1.is_eligible()
# Out:
# Student Name: Alice
# Age: 16
# Grade: A
# Alice is eligible for admission.

# %%
student2 = Student("Maria", 14, "B")
student2.display_info()
student2.is_eligible()
# Out:
# Student Name: Maria
# Age: 14
# Grade: B
# Maria is not eligible for admission.

# %% [markdown]
# Topic 34 | Encapsulation in Python - Public & Private Attributes
# This topic explains encapsulation and how to make attributes private. Learners understand how to protect data inside classes.

# %%
class Student:
    def __init__(self, name, grade):
        self.__grade = grade    # private attribute
student1 = Student("Umair", "A")
print(student1.Student__grade)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 5
#       1 class Student:
#       2     def __init__(self, name, grade):
#       3         self.__grade = grade
#       4 student1 = Student("Umair", "A")
# ----> 5 print(student1.Student__grade)
#
# AttributeError: 'Student' object has no attribute 'Student__grade'

# %%
class Student:
    def __init__(self, name, grade):
        self.__grade = grade    # private attribute

    def get_grade(self):
        return self.__grade      # public method to access the private attribute

student1 = Student("Umair", "90")
print(student1.get_grade())
# Out:
# 90

# %% [markdown]
# Topic 35 | Using Getters & Setters in Python
# This topic teaches how getters and setters control access to private attributes. Learners understand safe data handling in OOP.

# %%
class Student:
  @property
  def grade(self):
    return self.__grade
  def __init__(self, name, grade):
    self.__grade = grade
  def get_grade(self):    # getter method to access the private attribute
    return self.__grade
  def set_grade(self, grade):   # setter method to modify the private attribute with validation
   if 0 <= grade <= 100:
    self.__grade = grade
   else:
    print("Invalid grade!")



student = Student("Ali", 85)
student.set_grade(95)
print(student.get_grade())
# Out:
# 95

# %% [markdown]
# Topic 36 | Inheritance in Python - Parent & Child Classes
# This topic explains how child classes inherit attributes and methods from parent classes. Learners understand code reuse and hierarchy.

# %%
class Animal:
    def speak(self):
        print("The animal makes a sound.")

# %%
class dog(Animal):
    pass

# %%
dog1 = dog()

# %%
dog1.speak()
# Out:
# The animal makes a sound.

# %%
class Dog(Animal):
    def bark(self):
        print("The dog barks.")

# %%
adult_dog = Dog()
adult_dog.bark()
# Out:
# The dog barks.

# %%
adult_dog.speak()   #Inheritance allows the Dog class to use the speak() method from the Animal class
# Out:
# The animal makes a sound.

# %% [markdown]
# Topic 37 | Method Overriding
# This topic covers redefining methods in child classes to customize behavior. Learners understand how overriding supports flexible design.

# %%
class Animal:
    def speak(self):
        print("The animal makes a sound.")
class Dog(Animal):
    def speak(self):
        print("The dog barks.")
dog1 = Dog()
dog1.speak()
# Out:
# The dog barks.

# %% [markdown]
# Topic 38 | Polymorphism in Python - Overriding & Overloading
# This topic explains polymorphism and how Python supports it through overriding and overloading. Learners see how one interface can work with multiple forms.

# %%
class Dog:
    def speak(self):
        print("The dog barks.")

# %%
class Cat:
    def speak(self):
        print("The cat meows.")

# %%
for pet in [Dog(), Cat()]:
    pet.speak()
# Out:
# The dog barks.
# The cat meows.

# %%
class Vehicle:
    def move(self):
        print("The vehicle is moving.")

# %%
class Car(Vehicle):
    def move(self):
        print("The car is driving.")

# %%
car1 = Car()
car1.move()
# Out:
# The car is driving.

# %%
class Calculator:
    def add(self, a, b=0, c=0):
        return a + b + c
calc1 = Calculator()
print(calc1.add(5))
print(calc1.add(5, 10))
print(calc1.add(5, 10, 15))
# Out:
# 5
# 15
# 30

# %% [markdown]
# Topic 39 | Python Special Methods
# This topic introduces special methods like str and repr that customize object behavior. Learners understand how to make objects more intuitive.

# %%
class Book:
    def __init__(self, title, author):
        self.title = title
        self.author = author
    def __str__(self):
        return f"{self.title} by {self.author}"

# %%
b = Book("1982", "George Orwell")
print(b)
# Out:
# 1982 by George Orwell

# %%
class Playlist:
    def __init__(self, songs):
        self.songs = songs
    def __len__(self):
        return len(self.songs)
    def __add__(self, other):
        return Playlist(self.songs + other.songs)

p1 = Playlist(["Song1", "Song2"])
p2 = Playlist(["Song3"])
print(len(p1))
print(len(p1 + p2))
# Out:
# 2
# 3

# %%
class Point:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __str__(self):
        return f"({self.x}, {self.y})"
    def __add__(self, other):
        if not isinstance(other, Point):
            return NotImplemented
        return Point(self.x + other.x, self.y + other.y)

p1 = Point(2, 3)
p2 = Point(4, 1)
print(p1 + p2)
# Out:
# (6, 4)

# %% [markdown]
# Topic 40 | Reading from & Writing to Files in Python
# This topic teaches how to read and write different file types. Learners understand how Python handles external data.

# %%
file = open("demo.txt", "r")
print(file.read())
# Out:
# ðŸ”¹ Free Online Courses and Certifications
# ðŸ”¹ Python, Data Science and AI Free Courses
# ðŸ”¹ FREE ISO CERTIFIED CERTIFICATIONS

# %%
file.close()

# %%
file = open("demo.txt", "w")
file.write("Hello, this is a demo file.")
file.close()

# %%
file = open("demo.txt", "r")
print(file.read())
file.close()
# Out:
# Hello, this is a demo file.

# %% [markdown]
# Topic 41 | Modes of File Handling - Read, Write & Append
# This topic explains file modes (r, w, a) and how to use them. Learners practice opening, reading, and writing files.

# %%
file = open("demo.txt", "a")
file.write("\nThis is an additional line.")
file.close()

# %%
file = open("demo.txt", "r")
print(file.read())
file.close()
# Out:
# Hello, this is a demo file.This is an additional line.This is an additional line.
# This is an additional line.

# %% [markdown]
# Topic 42 | Using Context Managers (with Statement)
# This topic introduces the with statement for safe file handling. Learners understand how context managers simplify resource management.

# %%
# Using with statement to handle file operations
with open("demo.txt", "r") as file:
    data = file.read()
    print(data)
# Out:
# Hello, this is a demo file.This is an additional line.This is an additional line.
# This is an additional line.

# %% [markdown]
# Topic 43 | Handling Exceptions During File Operations
# This topic covers common file‐related errors and how to handle them. Learners gain confidence in writing error‐resilient code.

# %%
with open("demo.txt", "r") as file:
    print(file.read())
# Out:
# Hello, this is a demo file.This is an additional line.This is an additional line.
# This is an additional line.

# %%
# Handling file not found error
try:
    with open("readme.txt", "r") as file:
        print(file.read())
except FileNotFoundError:
    print("File not found.")
# Out:
# File not found.

# %%
filename = "my_info.txt"
name = "github Copilot"
age = 12

# %%
try:
    with open(filename, "r") as file:
        print(file.read())
except FileNotFoundError:
    with open(filename, "w") as fout:
        fout.write(f"Name: {name}\nAge: {age}")
    with open(filename, "r") as fin:
        print(fin.read())
# Out:
# Name: github Copilot
# Age: 12

# %% [markdown]
# Topic 44 | Introduction to Exceptions in Python
# This topic explains what exceptions are and why they occur. Learners understand how Python handles runtime errors.
# Using the except in code to handle the error

# %% [markdown]
# Topic 45 | Using try, except, else & finally Blocks
# This topic teaches structured error handling using try‐except blocks. Learners learn how to manage errors gracefully.

# %%
num = int(input("Enter a number: "))
print(10 / num)
# Out:
# 2.5

# %%
try:
    num = int(input("Enter a number: "))
    print(10 / num)
except ZeroDivisionError:
    print("Cannot divide by zero!")
except ValueError:
    print("Invalid input! Please enter a valid number.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Invalid input! Please enter a valid number.

# %%
try:
    print("Running the code......")
except:
    print("error found")
else:
    print("No error Found")
finally:
    print("Done!")
# Out:
# Running the code......
# No error Found
# Done!

# %% [markdown]
# Topic 46 | Raising Exceptions in Python
# This topic explains how to raise exceptions intentionally to enforce rules. Learners understand custom error signaling.

# %%
age = -3
if age < 0:
    raise ValueError("Age cannot be negative.")   #Raising a custom exception for invalid age
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 3
#       1 age = -3
#       2 if age < 0:
# ----> 3     raise ValueError("Age cannot be negative.")
#
# ValueError: Age cannot be negative.

# %% [markdown]
# Topic 47 | Creating Custom Exceptions in Python
# This topic teaches how to create custom exception classes. Learners understand how to design meaningful error messages.

# %%
class InvalidAgeError(Exception):
    pass

# %%
age = int(input("Enter your age: "))
if age <= 0:
    raise InvalidAgeError("Age cannot be zero or negative!")
# Out:
# ---------------------------------------------------------------------------
# InvalidAgeError                           Traceback (most recent call last)
# Cell In[42], line 3
#       1 age = int(input("Enter your age: "))
#       2 if age <= 0:
# ----> 3     raise InvalidAgeError("Age cannot be zero or negative!")
#
# InvalidAgeError: Age cannot be zero or negative!

# %%
try:
    age = int(input("Enter age: "))
    if age <= 0:
        raise InvalidAgeError("Age cannot be zero or negative!", {age})
except InvalidAgeError as e:
    print(f"Invalid age error: {e}")
# Out:
# Invalid age error: ('Age cannot be zero or negative!', {0})
